# %%
import json
a =[{'source': 'caroline', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'relationship': 'greeting', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:32', 'destination': 'melanie', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:8', 'similarity': 1.0}, {'source': 'melanie', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:8', 'relationship': 'greeting', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:33', 'destination': 'caroline', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'similarity': 1.0}, {'source': 'melanie', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:8', 'relationship': 'busy', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:34', 'destination': 'kids_and_work', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:29', 'similarity': 1.0}, {'source': 'caroline', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'relationship': 'asked_about', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:35', 'destination': 'melanie', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:8', 'similarity': 1.0}, {'source': 'caroline', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'relationship': 'attended', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:36', 'destination': 'lgbtq_support_group', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:31', 'similarity': 1.0}, {'source': 'caroline', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'relationship': 'felt', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:37', 'destination': 'inspired_by_transgender_stories', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:57', 'similarity': 1.0}, {'source': 'caroline', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'relationship': 'emotion', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:38', 'destination': 'happy', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:59', 'similarity': 1.0}, {'source': 'caroline', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'relationship': 'emotion', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:39', 'destination': 'thankful_for_support', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:72', 'similarity': 1.0}, {'source': 'caroline', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'relationship': 'felt_accepted_by', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:40', 'destination': 'support_group', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:73', 'similarity': 1.0}, {'source': 'caroline', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'relationship': 'gained_courage_from', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:41', 'destination': 'support_group', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:73', 'similarity': 1.0}, {'source': 'caroline', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'relationship': 'continuing_education', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:42', 'destination': 'edu', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:495', 'similarity': 1.0}, {'source': 'caroline', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'relationship': 'exploring', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:43', 'destination': 'career_options', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:507', 'similarity': 1.0}, {'source': 'melanie', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:8', 'relationship': 'reacting_to', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:44', 'destination': 'caroline', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'similarity': 1.0}, {'source': 'caroline', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'relationship': 'interested_in', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:45', 'destination': 'counseling', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:508', 'similarity': 1.0}, {'source': 'caroline', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'relationship': 'interested_in', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:46', 'destination': 'mental_health', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:514', 'similarity': 1.0}, {'source': 'melanie', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:8', 'relationship': 'thinks_will_be_good_at', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:47', 'destination': 'counselor', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:516', 'similarity': 1.0}, {'source': 'melanie', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:8', 'relationship': 'advises_to_look_at', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:48', 'destination': 'this', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:519', 'similarity': 1.0}, {'source': 'caroline', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'relationship': 'thanked', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:49', 'destination': 'melanie', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:8', 'similarity': 1.0}, {'source': 'melanie', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:8', 'relationship': 'painted', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:50', 'destination': 'lake_sunrise_painting', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:529', 'similarity': 1.0}, {'source': 'melanie', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:8', 'relationship': 'owns', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:51', 'destination': 'lake_sunrise_painting', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:529', 'similarity': 1.0}, {'source': 'caroline', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'relationship': 'complimented', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:52', 'destination': 'melanie', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:8', 'similarity': 1.0}, {'source': 'melanie', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:8', 'relationship': 'thanked', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:53', 'destination': 'caroline', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'similarity': 1.0}, {'source': 'melanie', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:8', 'relationship': 'expresses_feelings_through', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:54', 'destination': 'painting', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:534', 'similarity': 1.0}, {'source': 'melanie', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:8', 'relationship': 'relaxes_with', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:55', 'destination': 'painting', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:534', 'similarity': 1.0}, {'source': 'caroline', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'relationship': 'plans_to_continue_education', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:56', 'destination': 'edu', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:495', 'similarity': 1.0}, {'source': 'caroline', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'relationship': 'exploring_career_options', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:57', 'destination': 'career_options', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:507', 'similarity': 1.0}, {'source': 'caroline', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'relationship': 'emotion', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:58', 'destination': 'thankful for support', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:535', 'similarity': 1.0}, {'source': 'melanie', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:8', 'relationship': 'inquiring_about', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:59', 'destination': "caroline's_job_interests", 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:548', 'similarity': 1.0}, {'source': 'melanie', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:8', 'relationship': 'painted', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:60', 'destination': 'lake sunrise painting', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:550', 'similarity': 1.0}, {'source': 'melanie', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:8', 'relationship': 'owns', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:61', 'destination': 'lake sunrise painting', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:550', 'similarity': 1.0}, {'source': 'caroline', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'relationship': 'agrees_with', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:62', 'destination': 'melanie', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:8', 'similarity': 1.0}, {'source': 'melanie', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:8', 'relationship': 'busy', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:63', 'destination': 'kids', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:576', 'similarity': 1.0}, {'source': 'melanie', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:8', 'relationship': 'busy', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:64', 'destination': 'work', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:589', 'similarity': 1.0}, {'source': 'caroline', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'relationship': 'ask_about', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:65', 'destination': 'melanie', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:8', 'similarity': 1.0}, {'source': 'caroline', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'relationship': 'felt', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:66', 'destination': 'inspired', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:590', 'similarity': 1.0}, {'source': 'caroline', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'relationship': 'emotion', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:67', 'destination': 'thankful', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:596', 'similarity': 1.0}, {'source': 'caroline', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'relationship': 'received', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:68', 'destination': 'support', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:600', 'similarity': 1.0}, {'source': 'caroline', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'relationship': 'had_feeling', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:69', 'destination': 'happy', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:59', 'similarity': 1.0}, {'source': 'caroline', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'relationship': 'had_feeling', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:70', 'destination': 'thankful', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:596', 'similarity': 1.0}, {'source': 'melanie', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:8', 'relationship': 'asking_about', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:71', 'destination': 'caroline', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'similarity': 1.0}, {'source': 'melanie', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:8', 'relationship': 'thinks_will_be_good_at', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:72', 'destination': 'counseling', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:508', 'similarity': 1.0}, {'source': 'melanie', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:8', 'relationship': 'agrees_with', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:73', 'destination': 'caroline', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'similarity': 1.0}, {'source': 'melanie', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:8', 'relationship': 'inquiring', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:74', 'destination': 'caroline', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'similarity': 1.0}, {'source': 'caroline', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'relationship': 'felt', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:75', 'destination': 'happy', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:59', 'similarity': 1.0}, {'source': 'caroline', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'relationship': 'felt', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:76', 'destination': 'thankful', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:596', 'similarity': 1.0}, {'source': 'caroline', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'relationship': 'interested_in', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:77', 'destination': 'working_in_mental_health', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:612', 'similarity': 1.0}, {'source': 'caroline', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'relationship': 'agree_with', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:78', 'destination': 'melanie', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:8', 'similarity': 1.0}, {'source': 'melanie', 'source_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:8', 'relationship': 'agree_with', 'relation_id': '5:e8fefc69-b799-44d3-a764-a1fd48e419e3:79', 'destination': 'caroline', 'destination_id': '4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5', 'similarity': 1.0}]
# a =a[0]
# json.dump(a,open("output.json","w"))
print(json.dumps(a, indent=2))
b = json.loads(json.dumps(a))
print(len(b))
# Out:
# [
#   {
#     "source": "caroline",
#     "source_id": "4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5",
#     "relationship": "greeting",
#     "relation_id": "5:e8fefc69-b799-44d3-a764-a1fd48e419e3:32",
#     "destination": "melanie",
#     "destination_id": "4:e8fefc69-b799-44d3-a764-a1fd48e419e3:8",
#     "similarity": 1.0
#   },
#   {
#     "source": "melanie",
#     "source_id": "4:e8fefc69-b799-44d3-a764-a1fd48e419e3:8",
#     "relationship": "greeting",
#     "relation_id": "5:e8fefc69-b799-44d3-a764-a1fd48e419e3:33",
#     "destination": "caroline",
#     "destination_id": "4:e8fefc69-b799-44d3-a764-a1fd48e419e3:5",
#     "similarity": 1.0
#   },
#   {
#     "source": "melanie",
#     "source_id": "4:e8fefc69-b799-44d3-a764-a1fd48e419e3:8",
#     "relationship": "busy",
#     "relation_id": "5:e8fefc69-b799-44d3-a764-a1fd48e419e3:34",
#     "destination": "kids_and_work",
#     "destination_id": "4:e8fefc69-b799-44d3-a764-a1fd48e419e3:29",
#     "similarity": 1.0
#   },
#   {
# ...
