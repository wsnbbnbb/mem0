# %%
import os
from typing import List, Dict
import sys
sys.path.append('/root/nfs/hmj/proj/mem0')
from mem0 import Memory
from datetime import datetime
import anthropic

# Set up environment variables
os.environ["OPENAI_API_KEY"] = "sk-O5gUw11aOuFABJ7I2PdUHovEtQsWtNawaeoyQ3Pql9DVwsAk"  # needed for embedding model
os.environ["ANTHROPIC_API_KEY"] = "sk-O5gUw11aOuFABJ7I2PdUHovEtQsWtNawaeoyQ3Pql9DVwsAk"

# %%
class SupportChatbot:
    def __init__(self):
        # Initialize Mem0 with Anthropic's Claude
        self.config = {
            "llm": {
                "provider": "anthropic",
                "config": {
                    "model": "claude-3-5-sonnet-latest",
                    "temperature": 0.1,
                    "max_tokens": 2000,
                },
            }
        }
        self.client = anthropic.Client(api_key=os.environ["ANTHROPIC_API_KEY"])
        self.memory = Memory.from_config(self.config)

        # Define support context
        self.system_context = """
        You are a helpful customer support agent. Use the following guidelines:
        - Be polite and professional
        - Show empathy for customer issues
        - Reference past interactions when relevant
        - Maintain consistent information across conversations
        - If you're unsure about something, ask for clarification
        - Keep track of open issues and follow-ups
        """

    def store_customer_interaction(self, user_id: str, message: str, response: str, metadata: Dict = None):
        """Store customer interaction in memory."""
        if metadata is None:
            metadata = {}

        # Add timestamp to metadata
        metadata["timestamp"] = datetime.now().isoformat()

        # Format conversation for storage
        conversation = [{"role": "user", "content": message}, {"role": "assistant", "content": response}]

        # Store in Mem0
        self.memory.add(conversation, user_id=user_id, metadata=metadata)

    def get_relevant_history(self, user_id: str, query: str) -> List[Dict]:
        """Retrieve relevant past interactions."""
        return self.memory.search(
            query=query,
            user_id=user_id,
            limit=5,  # Adjust based on needs
        )

    def handle_customer_query(self, user_id: str, query: str) -> str:
        """Process customer query with context from past interactions."""

        # Get relevant past interactions
        relevant_history = self.get_relevant_history(user_id, query)

        # Build context from relevant history
        context = "Previous relevant interactions:\n"
        for memory in relevant_history:
            context += f"Customer: {memory['memory']}\n"
            context += f"Support: {memory['memory']}\n"
            context += "---\n"

        # Prepare prompt with context and current query
        prompt = f"""
        {self.system_context}

        {context}

        Current customer query: {query}

        Provide a helpful response that takes into account any relevant past interactions.
        """

        # Generate response using Claude
        response = self.client.messages.create(
            model="claude-3-5-sonnet-latest",
            messages=[{"role": "user", "content": prompt}],
            max_tokens=2000,
            temperature=0.1,
        )

        # Store interaction
        self.store_customer_interaction(
            user_id=user_id, message=query, response=response, metadata={"type": "support_query"}
        )

        return response.content[0].text

# %%
chatbot = SupportChatbot()
user_id = "customer_bot"
print("Welcome to Customer Support! Type 'exit' to end the conversation.")

while True:
    # Get user input
    query = input()
    print("Customer:", query)

    # Check if user wants to exit
    if query.lower() == "exit":
        print("Thank you for using our support service. Goodbye!")
        break

    # Handle the query and print the response
    response = chatbot.handle_customer_query(user_id, query)
    print("Support:", response, "\n\n")
# Out:
# Welcome to Customer Support! Type 'exit' to end the conversation.
# Customer:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[13], line 16
#      13     break
#      15 # Handle the query and print the response
# ---> 16 response = chatbot.handle_customer_query(user_id, query)
#      17 print("Support:", response, "\n\n")
#
# Cell In[12], line 54, in SupportChatbot.handle_customer_query(self, user_id, query)
#      51 """Process customer query with context from past interactions."""
#      53 # Get relevant past interactions
# ---> 54 relevant_history = self.get_relevant_history(user_id, query)
#      56 # Build context from relevant history
#      57 context = "Previous relevant interactions:\n"
#
# Cell In[12], line 44, in SupportChatbot.get_relevant_history(self, user_id, query)
#      42 def get_relevant_history(self, user_id: str, query: str) -> List[Dict]:
#      43     """Retrieve relevant past interactions."""
# ---> 44     return self.memory.search(
#      45         query=query,
#      46         user_id=user_id,
#      47         limit=5,  # Adjust based on needs
#      48     )
#
# File /opt/conda/envs/py10/lib/python3.10/site-packages/mem0/memory/main.py:672, in Memory.search(self, query, user_id, agent_id, run_id, limit, filters, threshold)
#     664     future_graph_entities = (
#     665         executor.submit(self.graph.search, query, effective_filters, limit) if self.enable_graph else None
#     666     )
#     668     concurrent.futures.wait(
#     669         [future_memories, future_graph_entities] if future_graph_entities else [future_memories]
#     670     )
# --> 672     original_memories = future_memories.result()
#     673     graph_entities = future_graph_entities.result() if future_graph_entities else None
#     675 if self.enable_graph:
#
# File /opt/conda/envs/py10/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/conda/envs/py10/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File /opt/conda/envs/py10/lib/python3.10/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File /opt/conda/envs/py10/lib/python3.10/site-packages/mem0/memory/main.py:691, in Memory._search_vector_store(self, query, filters, limit, threshold)
#     690 def _search_vector_store(self, query, filters, limit, threshold: Optional[float] = None):
# --> 691     embeddings = self.embedding_model.embed(query, "search")
#     692     memories = self.vector_store.search(query=query, vectors=embeddings, limit=limit, filters=filters)
#     694     promoted_payload_keys = [
#     695         "user_id",
#     696         "agent_id",
#    (...)
#     699         "role",
#     700     ]
#
# File /opt/conda/envs/py10/lib/python3.10/site-packages/mem0/embeddings/openai.py:46, in OpenAIEmbedding.embed(self, text, memory_action)
#      35 """
#      36 Get the embedding for the given text using OpenAI.
#      37
#    (...)
#      42     list: The embedding vector.
#      43 """
#      44 text = text.replace("\n", " ")
#      45 return (
# ---> 46     self.client.embeddings.create(input=[text], model=self.config.model, dimensions=self.config.embedding_dims)
#      47     .data[0]
#      48     .embedding
#      49 )
#
# File /opt/conda/envs/py10/lib/python3.10/site-packages/openai/resources/embeddings.py:132, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     126             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     127                 base64.b64decode(data), dtype="float32"
#     128             ).tolist()
#     130     return obj
# --> 132 return self._post(
#     133     "/embeddings",
#     134     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     135     options=make_request_options(
#     136         extra_headers=extra_headers,
#     137         extra_query=extra_query,
#     138         extra_body=extra_body,
#     139         timeout=timeout,
#     140         post_parser=parser,
#     141     ),
#     142     cast_to=CreateEmbeddingResponse,
#     143 )
#
# File /opt/conda/envs/py10/lib/python3.10/site-packages/openai/_base_client.py:1256, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1242 def post(
#    1243     self,
#    1244     path: str,
#    (...)
#    1251     stream_cls: type[_StreamT] | None = None,
#    1252 ) -> ResponseT | _StreamT:
#    1253     opts = FinalRequestOptions.construct(
#    1254         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1255     )
# -> 1256     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /opt/conda/envs/py10/lib/python3.10/site-packages/openai/_base_client.py:1044, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1041             err.response.read()
#    1043         log.debug("Re-raising status error")
# -> 1044         raise self._make_status_error_from_response(err.response) from None
#    1046     break
#    1048 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-O5gUw***************************************wsAk. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
